# %% [markdown]
# **These steps were done for Toxicity Test data on my local**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv
import numpy as np 
import nltk
nltk.download('punkt')

import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ### Perspective Scores of Training Set
# Scores for Test Set done on local

# %%
import time 
import requests
import json
import random

# %%
def get_score(text):
    api_key = 'AIzaSyDcHE3PPBdKxZFm2a075M_RuIvRL9-ATws'
    url = ('https://commentanalyzer.googleapis.com/v1alpha1/comments:analyze' +    
                '?key=' + api_key)
    data_dict = {
        'comment': {'text': text},
        'languages': ['en'],
        'requestedAttributes': {'TOXICITY': {}}
    }
    response = requests.post(url=url, data=json.dumps(data_dict))
    # print(str(response.content))    
    response_dict = json.loads(response.content.decode('utf-8'))
    # print(text)
    # print(response_dict['attributeScores']['TOXICITY']['summaryScore']['value'])
    # print(json.dumps(response_dict, indent=2))
    return response_dict['attributeScores']['TOXICITY']['summaryScore']['value']

# %%
toxicity_training_file = '/content/drive/My Drive/Incivility/Perspective/Perspective_Error_Analysis/train_data/toxicity.csv'
dataset = []
with open(toxicity_training_file) as f:
	reader = csv.reader(f)
	for i, row in enumerate(reader):
		new_row = [''.join(row[:-1]), row[-1]]
		dataset.append(new_row)

# %%
# random.seed(2020)
# indices = list(range(1, len(dataset)+1))
# random.shuffle(indices)
# np.save('/content/drive/My Drive/Incivility/News/Perspective_Error_Analysis/train_shuffled_indices.npy', indices)

# %%
indices = np.load('/content/drive/My Drive/Incivility/Perspective/Perspective_Error_Analysis/train_data/train_shuffled_indices.npy').tolist()

with open('/content/drive/My Drive/Incivility/Perspective/Perspective_Error_Analysis/train_data/toxicity_train_subset_errors_11.csv', 'w') as w:
    
    writer = csv.writer(w)
    writer.writerow(['Index', 'Text', 'Label', 'Perspective'])
    
    M = 284812 # CHANGE HERE
    
    for i, index in enumerate(indices):
        # rows already covered in previous rounds
        if i <= M or index <= 19023:
            continue
        if i > M + 20000:
            break
        else:
            if (i+1) % 1000 == 0:
                print('clip: ', i+1)

            text, label_score = dataset[index][0], float(dataset[index][1])      
            perspective_score = get_score(text)
            writer.writerow([index, text, label_score, perspective_score])

            time.sleep(2)
# Out:
# clip:  265000
# clip:  266000
# clip:  267000

# %%
# toxicity_training_file = '/content/drive/My Drive/Incivility/News/Perspective_Error_Analysis/toxicity.csv'
# dataset = []
# with open(toxicity_training_file) as f:
# 	reader = csv.reader(f)
# 	for i, row in enumerate(reader):
# 		new_row = [''.join(row[:-1]), row[-1]]
# 		dataset.append(new_row)

# %%
# sex_words = ['arse', 'molester', 'asses', 'dick', 'Transgender', 'abort', 'raped', 'lesbians', 'intercourse', 'virgin', 'breasts', 'rapist', 'butt', 'porn', 'pedophile', 'groping', 'naked', 'genital', 'pimp', 'homosexuals', 'pervert', 'butts', 'perverted', 'prostitutes', 'Gays', 'balls', 'rapists', 'homosexuality', 'gays']

# with open('Vocabulary_Average_Errors.csv') as f:
#     header = f.readline()
#     reader = csv.reader(f)

#     vocabulary = [row[0] for row in reader]

# cooccurences = {}
# sex_occurrences = {}
# for row in dataset:
#     words = nltk.word_tokenize(row[0])
