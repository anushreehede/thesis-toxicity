# %% [markdown]
# **These steps were done for Toxicity Test data on my local**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv
import numpy as np 
import nltk
nltk.download('punkt')

import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ### Perspective Scores of Training Set
# Scores for Test Set done on local

# %%
import time 
import requests
import json
import random

# %%
def get_score(text):
    api_key = 'AIzaSyDcHE3PPBdKxZFm2a075M_RuIvRL9-ATws'

    url = ('https://commentanalyzer.googleapis.com/v1alpha1/comments:analyze' +    
                '?key=' + api_key)

    data_dict = {
        'comment': {'text': text},
        'languages': ['en'],
        'requestedAttributes': {'TOXICITY': {}}
    }

    response = requests.post(url=url, data=json.dumps(data_dict))
    # print(str(response.content))    
    response_dict = json.loads(response.content.decode('utf-8'))
    
    # print(text)
    # print(response_dict['attributeScores']['TOXICITY']['summaryScore']['value'])
    # print(json.dumps(response_dict, indent=2))
    
    return response_dict['attributeScores']['TOXICITY']['summaryScore']['value']

# %%
toxicity_training_file = '/content/drive/My Drive/Incivility/News/Perspective_Error_Analysis/toxicity_train_errors.csv'

dataset = []
with open(toxicity_training_file) as f:
	header = f.readline()
	reader = csv.reader(f)
	for i, row in enumerate(reader):
		new_row = [''.join(row[:-2]), row[-2], row[-1]]
		dataset.append(new_row)

# %%
err_trigg_file = '/content/drive/My Drive/Incivility/News/Perspective_Error_Analysis/vocab_error_triggers.csv'

with open(err_trigg_file) as f:
    reader = csv.reader(f)
    error_triggers = [row[0] for row in reader]

# %%
# random.seed(2020)
# indices = list(range(1, len(dataset)+1))
# random.shuffle(indices)
# np.save('/content/drive/My Drive/Incivility/News/Perspective_Error_Analysis/train_shuffled_indices.npy', indices)

# %%
# indices = np.load('/content/drive/My Drive/Incivility/News/Perspective_Error_Analysis/train_shuffled_indices.npy').tolist()

with open('/content/drive/My Drive/Incivility/News/Perspective_Error_Analysis/toxicity_train_subset_errors_remove_triggers.csv', 'w') as w:
    
    writer = csv.writer(w)
    writer.writerow(['Index', 'Text', 'Label', 'Perspective', 'Filtered Text', 'New Perspective'])

    for i, row in enumerate(dataset):

        if (i+1) % 100 == 0:
            print('clip: ', i+1)

        text, label_score = row[0], float(row[1])
        words = nltk.word_tokenize(text)

        filtered_words = [word for word in words if word not in error_triggers]
        filtered_text = ' '.join(filtered_words)

        perspective_score = get_score(filtered_text)
        writer.writerow([i, text, label_score, float(row[2]), filtered_text, perspective_score])

        time.sleep(2)
# Out:
# clip:  100
# clip:  200
# clip:  300
# clip:  400
# clip:  500
# clip:  600
# clip:  700
# clip:  800
# clip:  900
# clip:  1000
# clip:  1100
# clip:  1200
# clip:  1300
# clip:  1400
# clip:  1500
# clip:  1600
# clip:  1700
# clip:  1800
# clip:  1900
# clip:  2000
# clip:  2100
# clip:  2200
# clip:  2300
# clip:  2400
# clip:  2500
# clip:  2600
# clip:  2700
# clip:  2800
# clip:  2900
# clip:  3000
# clip:  3100
# clip:  3200
# clip:  3300
# clip:  3400
# clip:  3500
# clip:  3600
# clip:  3700
# clip:  3800
# clip:  3900
# clip:  4000
# clip:  4100
# clip:  4200
# clip:  4300
# clip:  4400
# clip:  4500
# clip:  4600
# clip:  4700
# clip:  4800
# clip:  4900
# clip:  5000
# clip:  5100
# clip:  5200
# clip:  5300
# clip:  5400
# clip:  5500
# clip:  5600
# clip:  5700
# clip:  5800
# clip:  5900
# clip:  6000
# clip:  6100
# clip:  6200
# clip:  6300
# clip:  6400
# clip:  6500
# clip:  6600
# clip:  6700
# clip:  6800
# clip:  6900
# clip:  7000
# clip:  7100
# clip:  7200
# ...
