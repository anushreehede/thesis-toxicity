# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv
import numpy as np 
import nltk
nltk.download('punkt')

import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import time 
import requests
import json
import random

# %%
def get_score(text):
    api_key = 'AIzaSyDcHE3PPBdKxZFm2a075M_RuIvRL9-ATws'
    url = ('https://commentanalyzer.googleapis.com/v1alpha1/comments:analyze' +    
                '?key=' + api_key)
    data_dict = {
        'comment': {'text': text},
        'languages': ['en'],
        'requestedAttributes': {'TOXICITY': {}}
    }
    response = requests.post(url=url, data=json.dumps(data_dict))
    # print(str(response.content))    
    response_dict = json.loads(response.content.decode('utf-8'))
    # print(text)
    # print(response_dict['attributeScores']['TOXICITY']['summaryScore']['value'])
    # print(json.dumps(response_dict, indent=2))
    return response_dict['attributeScores']['TOXICITY']['summaryScore']['value']

# %%
toxicity_test_file = '/content/drive/My Drive/Incivility/Perspective/Perspective_Error_Analysis/test_data/test_public_expanded.csv'
output_file = '/content/drive/My Drive/Incivility/Perspective/Perspective_Error_Analysis/test_data/Perspective_test_data_3.csv'
with open(toxicity_test_file) as f, open(output_file, 'w') as w:
    header = f.readline().split(',')
    comment_idx = header.index('comment_text') 
    score_idx = header.index('toxicity')
    reader = csv.reader(f)
    writer = csv.writer(w)
    h = ['Text', 'Label', 'Perspective']
    writer.writerow(h)
    for i, row in enumerate(reader):
        if i >= 84038-1:
            # print(row[comment_idx])
            if i % 1000 == 0:
                print(i)
            text = row[comment_idx]
            label = float(row[score_idx])
            score = get_score(text)
            new_row = [text, label, score]
            writer.writerow(new_row)
            time.sleep(2)
# Out:
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
